# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Read the data
df = pd.read_excel('./data/Date_Fruit_Datasets.xlsx', header= 0)

# split into input (X) and output (Y) variables
# y is the last column there are 35 columns
X = df.iloc[:,0:34]
Y = df.iloc[:,34]

# split into 67% for train and 33% for test
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=42)

# %%
# one hot encode outputs
label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_test = label_encoder.fit_transform(y_test)
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)
y_train[0]
# Out:
# array([0., 0., 1., 0., 0., 0., 0.], dtype=float32)

# %%
# normalize the data
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
# build the model
model = Sequential()

# input  layer with input dimension of 34 and relu activation function
model.add(Dense(34, input_dim=34, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(7, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_40 (Dense)            (None, 34)                1190
#
#  dense_41 (Dense)            (None, 128)               4480
#
#  dense_42 (Dense)            (None, 64)                8256
#
#  dense_43 (Dense)            (None, 32)                2080
#
#  dense_44 (Dense)            (None, 16)                528
#
#  dense_45 (Dense)            (None, 7)                 119
#
# =================================================================
# Total params: 16,653
# Trainable params: 16,653
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# fit the model
history = model.fit(x_train, y_train, validation_data=(x_test,y_test), epochs=100, batch_size=5)
# Out:
# Epoch 1/100
# 153/153 [==============================] - 1s 3ms/step - loss: 1.8398 - accuracy: 0.2844 - val_loss: 1.6181 - val_accuracy: 0.4370
# Epoch 2/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.4713 - accuracy: 0.4168 - val_loss: 1.5133 - val_accuracy: 0.3704
# Epoch 3/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.3960 - accuracy: 0.4351 - val_loss: 1.4617 - val_accuracy: 0.4000
# Epoch 4/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.3746 - accuracy: 0.4181 - val_loss: 1.3908 - val_accuracy: 0.3556
# Epoch 5/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.3592 - accuracy: 0.4338 - val_loss: 1.3883 - val_accuracy: 0.4444
# Epoch 6/100
# 153/153 [==============================] - 0s 3ms/step - loss: 1.3409 - accuracy: 0.4744 - val_loss: 1.3777 - val_accuracy: 0.4667
# Epoch 7/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.3206 - accuracy: 0.4640 - val_loss: 1.3901 - val_accuracy: 0.4148
# Epoch 8/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.3305 - accuracy: 0.4758 - val_loss: 1.3194 - val_accuracy: 0.4963
# Epoch 9/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.2934 - accuracy: 0.5177 - val_loss: 1.3395 - val_accuracy: 0.5111
# Epoch 10/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.2727 - accuracy: 0.5033 - val_loss: 1.4274 - val_accuracy: 0.4519
# Epoch 11/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.2661 - accuracy: 0.5138 - val_loss: 1.3407 - val_accuracy: 0.4815
# Epoch 12/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.2565 - accuracy: 0.5334 - val_loss: 1.2943 - val_accuracy: 0.4815
# Epoch 13/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.2634 - accuracy: 0.4889 - val_loss: 1.3141 - val_accuracy: 0.5111
# Epoch 14/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.2465 - accuracy: 0.5059 - val_loss: 1.2916 - val_accuracy: 0.5481
# Epoch 15/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.2436 - accuracy: 0.5190 - val_loss: 1.2651 - val_accuracy: 0.5111
# Epoch 16/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.2397 - accuracy: 0.5229 - val_loss: 1.3312 - val_accuracy: 0.4889
# Epoch 17/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.2213 - accuracy: 0.5321 - val_loss: 1.2846 - val_accuracy: 0.5037
# Epoch 18/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.2423 - accuracy: 0.5216 - val_loss: 1.3406 - val_accuracy: 0.5037
# Epoch 19/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.2303 - accuracy: 0.5190 - val_loss: 1.2951 - val_accuracy: 0.5185
# Epoch 20/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.2133 - accuracy: 0.5334 - val_loss: 1.2727 - val_accuracy: 0.5481
# Epoch 21/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.2496 - accuracy: 0.5321 - val_loss: 1.2726 - val_accuracy: 0.5111
# Epoch 22/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1992 - accuracy: 0.5374 - val_loss: 1.4552 - val_accuracy: 0.4593
# Epoch 23/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.2217 - accuracy: 0.5649 - val_loss: 1.4217 - val_accuracy: 0.3852
# Epoch 24/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1843 - accuracy: 0.5360 - val_loss: 1.4712 - val_accuracy: 0.4074
# Epoch 25/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.2156 - accuracy: 0.5426 - val_loss: 1.2444 - val_accuracy: 0.4889
# Epoch 26/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.2004 - accuracy: 0.5242 - val_loss: 1.2441 - val_accuracy: 0.5481
# Epoch 27/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1774 - accuracy: 0.5439 - val_loss: 1.2986 - val_accuracy: 0.4889
# Epoch 28/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1598 - accuracy: 0.5478 - val_loss: 1.2401 - val_accuracy: 0.5630
# Epoch 29/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1683 - accuracy: 0.5636 - val_loss: 1.2347 - val_accuracy: 0.5259
# Epoch 30/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1583 - accuracy: 0.5714 - val_loss: 1.2425 - val_accuracy: 0.5037
# Epoch 31/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1632 - accuracy: 0.5505 - val_loss: 1.2069 - val_accuracy: 0.5630
# Epoch 32/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1458 - accuracy: 0.5557 - val_loss: 1.2300 - val_accuracy: 0.5556
# Epoch 33/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1506 - accuracy: 0.5452 - val_loss: 1.2044 - val_accuracy: 0.5556
# Epoch 34/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1464 - accuracy: 0.5596 - val_loss: 1.3482 - val_accuracy: 0.4593
# Epoch 35/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1407 - accuracy: 0.5531 - val_loss: 1.2377 - val_accuracy: 0.5185
# Epoch 36/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1187 - accuracy: 0.5649 - val_loss: 1.2986 - val_accuracy: 0.5111
# Epoch 37/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1358 - accuracy: 0.5701 - val_loss: 1.2321 - val_accuracy: 0.5481
# Epoch 38/100
# 153/153 [==============================] - 0s 3ms/step - loss: 1.1142 - accuracy: 0.5636 - val_loss: 1.2802 - val_accuracy: 0.5111
# Epoch 39/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1254 - accuracy: 0.5714 - val_loss: 1.2702 - val_accuracy: 0.5185
# Epoch 40/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1370 - accuracy: 0.5662 - val_loss: 1.2593 - val_accuracy: 0.4815
# Epoch 41/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1205 - accuracy: 0.5609 - val_loss: 1.1780 - val_accuracy: 0.5481
# Epoch 42/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1184 - accuracy: 0.5675 - val_loss: 1.2705 - val_accuracy: 0.4815
# Epoch 43/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1239 - accuracy: 0.5662 - val_loss: 1.2361 - val_accuracy: 0.5185
# Epoch 44/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1071 - accuracy: 0.5557 - val_loss: 1.1773 - val_accuracy: 0.5259
# Epoch 45/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1142 - accuracy: 0.5767 - val_loss: 1.2008 - val_accuracy: 0.5481
# Epoch 46/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1141 - accuracy: 0.5727 - val_loss: 1.2849 - val_accuracy: 0.5259
# Epoch 47/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1489 - accuracy: 0.5583 - val_loss: 1.2381 - val_accuracy: 0.5481
# Epoch 48/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1149 - accuracy: 0.5583 - val_loss: 1.2033 - val_accuracy: 0.5259
# Epoch 49/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1284 - accuracy: 0.5675 - val_loss: 1.1910 - val_accuracy: 0.5481
# Epoch 50/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1095 - accuracy: 0.5727 - val_loss: 1.2314 - val_accuracy: 0.5259
# Epoch 51/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.0963 - accuracy: 0.5740 - val_loss: 1.1900 - val_accuracy: 0.5333
# Epoch 52/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1198 - accuracy: 0.5623 - val_loss: 1.2423 - val_accuracy: 0.5407
# Epoch 53/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1090 - accuracy: 0.5662 - val_loss: 1.3080 - val_accuracy: 0.4741
# Epoch 54/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1271 - accuracy: 0.5439 - val_loss: 1.2158 - val_accuracy: 0.5333
# Epoch 55/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1180 - accuracy: 0.5649 - val_loss: 1.2258 - val_accuracy: 0.5407
# Epoch 56/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1052 - accuracy: 0.5793 - val_loss: 1.1866 - val_accuracy: 0.5333
# Epoch 57/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1057 - accuracy: 0.5583 - val_loss: 1.2003 - val_accuracy: 0.5333
# Epoch 58/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.0987 - accuracy: 0.5688 - val_loss: 1.2484 - val_accuracy: 0.5333
# Epoch 59/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1134 - accuracy: 0.5491 - val_loss: 1.1761 - val_accuracy: 0.5259
# Epoch 60/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.0974 - accuracy: 0.5780 - val_loss: 1.2091 - val_accuracy: 0.5259
# Epoch 61/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1023 - accuracy: 0.5727 - val_loss: 1.2180 - val_accuracy: 0.5556
# Epoch 62/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1063 - accuracy: 0.5701 - val_loss: 1.2384 - val_accuracy: 0.5481
# Epoch 63/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.1077 - accuracy: 0.5688 - val_loss: 1.2587 - val_accuracy: 0.5037
# Epoch 64/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1087 - accuracy: 0.5557 - val_loss: 1.4626 - val_accuracy: 0.4222
# Epoch 65/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1352 - accuracy: 0.5505 - val_loss: 1.1770 - val_accuracy: 0.5407
# Epoch 66/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0849 - accuracy: 0.5714 - val_loss: 1.2728 - val_accuracy: 0.4815
# Epoch 67/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.0898 - accuracy: 0.5714 - val_loss: 1.1978 - val_accuracy: 0.5407
# Epoch 68/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.0930 - accuracy: 0.5858 - val_loss: 1.1576 - val_accuracy: 0.5481
# Epoch 69/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0850 - accuracy: 0.5688 - val_loss: 1.2561 - val_accuracy: 0.5111
# Epoch 70/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0936 - accuracy: 0.5714 - val_loss: 1.2257 - val_accuracy: 0.5481
# Epoch 71/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0924 - accuracy: 0.5754 - val_loss: 1.2198 - val_accuracy: 0.5407
# Epoch 72/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0853 - accuracy: 0.5740 - val_loss: 1.2604 - val_accuracy: 0.5111
# Epoch 73/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.0908 - accuracy: 0.5688 - val_loss: 1.2405 - val_accuracy: 0.4815
# Epoch 74/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.0976 - accuracy: 0.5701 - val_loss: 1.2146 - val_accuracy: 0.5630
# Epoch 75/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1005 - accuracy: 0.5596 - val_loss: 1.2239 - val_accuracy: 0.5185
# Epoch 76/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1292 - accuracy: 0.5544 - val_loss: 1.1998 - val_accuracy: 0.5481
# Epoch 77/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.0836 - accuracy: 0.5740 - val_loss: 1.1932 - val_accuracy: 0.5333
# Epoch 78/100
# 153/153 [==============================] - 0s 1ms/step - loss: 1.0834 - accuracy: 0.5832 - val_loss: 1.3153 - val_accuracy: 0.5037
# Epoch 79/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0914 - accuracy: 0.5649 - val_loss: 1.2125 - val_accuracy: 0.5333
# Epoch 80/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.1142 - accuracy: 0.5583 - val_loss: 1.2135 - val_accuracy: 0.5630
# Epoch 81/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0755 - accuracy: 0.5858 - val_loss: 1.2635 - val_accuracy: 0.4593
# Epoch 82/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0877 - accuracy: 0.5727 - val_loss: 1.2000 - val_accuracy: 0.5407
# Epoch 83/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0804 - accuracy: 0.5806 - val_loss: 1.2008 - val_accuracy: 0.5333
# Epoch 84/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0779 - accuracy: 0.5819 - val_loss: 1.1902 - val_accuracy: 0.5481
# Epoch 85/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0792 - accuracy: 0.5701 - val_loss: 1.2312 - val_accuracy: 0.5185
# Epoch 86/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0898 - accuracy: 0.5793 - val_loss: 1.2153 - val_accuracy: 0.5407
# Epoch 87/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0721 - accuracy: 0.5845 - val_loss: 1.2133 - val_accuracy: 0.5333
# Epoch 88/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0773 - accuracy: 0.5714 - val_loss: 1.2081 - val_accuracy: 0.5333
# Epoch 89/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0903 - accuracy: 0.5727 - val_loss: 1.1800 - val_accuracy: 0.5481
# Epoch 90/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0735 - accuracy: 0.5727 - val_loss: 1.2052 - val_accuracy: 0.5556
# Epoch 91/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0807 - accuracy: 0.5727 - val_loss: 1.2180 - val_accuracy: 0.5333
# Epoch 92/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0850 - accuracy: 0.5688 - val_loss: 1.1965 - val_accuracy: 0.5407
# Epoch 93/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0862 - accuracy: 0.5662 - val_loss: 1.1965 - val_accuracy: 0.5259
# Epoch 94/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0628 - accuracy: 0.5740 - val_loss: 1.2004 - val_accuracy: 0.5481
# Epoch 95/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0835 - accuracy: 0.5754 - val_loss: 1.2967 - val_accuracy: 0.5185
# Epoch 96/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0662 - accuracy: 0.5740 - val_loss: 1.1713 - val_accuracy: 0.5556
# Epoch 97/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0799 - accuracy: 0.5780 - val_loss: 1.2599 - val_accuracy: 0.5111
# Epoch 98/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0688 - accuracy: 0.5832 - val_loss: 1.3111 - val_accuracy: 0.5037
# Epoch 99/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0747 - accuracy: 0.5596 - val_loss: 1.2213 - val_accuracy: 0.5333
# Epoch 100/100
# 153/153 [==============================] - 0s 2ms/step - loss: 1.0691 - accuracy: 0.5727 - val_loss: 1.2043 - val_accuracy: 0.5407

# %%
# predict the test data
y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)
y_test = y_test.argmax(1)

# predict the training data
y_pred_train = model.predict(x_train)
y_pred_train = np.argmax(y_pred_train, axis=1)
y_train = y_train.argmax(1)


# precentage of correct prediction
correct = (y_pred == y_test).sum()
incorrect = (y_pred != y_test).sum()
accuracy = correct / (correct + incorrect) * 100
print('Accuracy: %.2f' % accuracy, '%')

# precentage of correct prediction
correct = (y_pred_train == y_train).sum()
incorrect = (y_pred_train != y_train).sum()
accuracy = correct / (correct + incorrect) * 100
print('Accuracy: %.2f' % accuracy, '%')
# Out:
# 5/5 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 1ms/step
# Accuracy: 54.07 %
# Accuracy: 58.58 %
